# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# # About Kelsey
#
# Welcome to my page
#
# ## HOW-TO-CODE 101
#
# I DUNNO
#
# ### how to get started
#
# being a DSAN student
#
# #### Then?
#
# guuuud

# %% [markdown]
# # Here is the code

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)

plt.title('Simple Line Plot')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
